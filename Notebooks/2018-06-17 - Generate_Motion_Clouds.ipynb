# %% [markdown]
# # 2018-05-15 - 16 thetas with MC
# Faut penser un peu a augmenter les datas, car il n'y avait que de 120 MC et 12 MC_test pour 16 orientations. En plus, dans un notebook indépendant on les retrouve mieux :

# %%
import numpy as np
import MotionClouds as mc
import matplotlib.pyplot as plt
import os
import imageio

downscale = 1
fig_width = 21
fx, fy, ft = mc.get_grids(mc.N_X/downscale, mc.N_Y/downscale, 1)

def generate_16_easy_MC(N_theta = 240, N_theta_test = 36):
    #16 angles entre 0 et pi
    theta_values = np.linspace(0,np.pi,16)

    bw_values = np.pi*np.logspace(-7,-3.5, N_theta, base=2)
    bw_test_values = np.pi*np.logspace(-7,-3.5, N_theta_test, base=2)

    #generer training
    for t in theta_values :
        if not os.path.exists('./16_clouds_easy/%s' % t): #si le folder n'existe pas on le crée
            os.makedirs('./16_clouds_easy/%s' % t)

        for i_ax, B_theta in enumerate(bw_values):
            mc_i = mc.envelope_gabor(fx, fy, ft, V_X=0., V_Y=0., B_V=0, theta=t, B_theta=B_theta)
            im = mc.random_cloud(mc_i)
            im = im
            imageio.imwrite('./16_clouds_easy/%s/B0 %s.png' % (t , (B_theta*180/np.pi) ) , im[:, :, 0])

    #generer test
    for t in theta_values :
        if not os.path.exists('./16_clouds_easy_test/%s' % t): #si le folder n'existe pas on le crée
            os.makedirs('./16_clouds_easy_test/%s' % t)

        for i_ax, B_theta in enumerate(bw_test_values):
            mc_i = mc.envelope_gabor(fx, fy, ft, V_X=0., V_Y=0., B_V=0, theta=t, B_theta=B_theta)
            im = mc.random_cloud(mc_i)

            imageio.imwrite('./16_clouds_easy_test/%s/B0 %s.png' % (t , (B_theta*180/np.pi) ) , im[:, :, 0])

            
def generate_16_medium_MC(N_theta = 240, N_theta_test = 36):
    #16 angles entre 0 et pi
    theta_values = np.linspace(0,np.pi,16)

    bw_values = np.pi*np.logspace(-7,-3.5, N_theta, base=2)
    bw_test_values = np.pi*np.logspace(-7,-3.5, N_theta_test, base=2)

    #generer training
    for t in theta_values :
        if not os.path.exists('./16_clouds_medium/%s' % t): #si le folder n'existe pas on le crée
            os.makedirs('./16_clouds_easy/%s' % t)

        for i_ax, B_theta in enumerate(bw_values):
            mc_i = mc.envelope_gabor(fx, fy, ft, V_X=0., V_Y=0., B_V=0, theta=t, B_theta=B_theta)
            im = mc.random_cloud(mc_i)
            im = im
            imageio.imwrite('./16_clouds_medium/%s/B0 %s.png' % (t , (B_theta*180/np.pi) ) , im[:, :, 0])

    #generer test
    for t in theta_values :
        if not os.path.exists('./16_clouds_medium_test/%s' % t): #si le folder n'existe pas on le crée
            os.makedirs('./16_clouds_medium_test/%s' % t)

        for i_ax, B_theta in enumerate(bw_test_values):
            mc_i = mc.envelope_gabor(fx, fy, ft, V_X=0., V_Y=0., B_V=0, theta=t, B_theta=B_theta)
            im = mc.random_cloud(mc_i)

            imageio.imwrite('./16_clouds_medium_test/%s/B0 %s.png' % (t , (B_theta*180/np.pi) ) , im[:, :, 0])
         
        
def generate_16_hard_MC(N_theta = 240, N_theta_test = 36):
    #16 angles entre 0 et pi
    theta_values = np.linspace(0,np.pi,16)

    bw_values = np.pi*np.logspace(-7,-3.5, N_theta, base=2)
    bw_test_values = np.pi*np.logspace(-7,-3.5, N_theta_test, base=2)

    #generer training
    for t in theta_values :
        if not os.path.exists('./16_clouds_hard/%s' % t): #si le folder n'existe pas on le crée
            os.makedirs('./16_clouds_hard/%s' % t)

        for i_ax, B_theta in enumerate(bw_values):
            mc_i = mc.envelope_gabor(fx, fy, ft, V_X=0., V_Y=0., B_V=0, theta=t, B_theta=B_theta)
            im = mc.random_cloud(mc_i)
            im = im
            imageio.imwrite('./16_clouds_hard/%s/B0 %s.png' % (t , (B_theta*180/np.pi) ) , im[:, :, 0])

    #generer test
    for t in theta_values :
        if not os.path.exists('./16_clouds_hard_test/%s' % t): #si le folder n'existe pas on le crée
            os.makedirs('./16_clouds_hard_test/%s' % t)

        for i_ax, B_theta in enumerate(bw_test_values):
            mc_i = mc.envelope_gabor(fx, fy, ft, V_X=0., V_Y=0., B_V=0, theta=t, B_theta=B_theta)
            im = mc.random_cloud(mc_i)

            imageio.imwrite('./16_clouds_hard_test/%s/B0 %s.png' % (t , (B_theta*180/np.pi) ) , im[:, :, 0])
            
generate_16_easy_MC()
# Out:
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.730137366389636e+177, 4.902355247379162e+177]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.1318640443192014e+174, 1.361994782167766e+174]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.798047097558184e+170, 3.198857979694572e+170]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.1568029489442174e+167, 9.448605772148988e+166]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.734249462290891e+163, 4.793322658351963e+163]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.976450538756555e+160, 1.6828831550618142e+160]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.2418718113152352e+157, 1.01571715725917e+157]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.751590380179323e+153, 6.122435795325024e+153]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-4.169776428150063e+150, 4.4119600194702834e+150]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.576581263784102e+147, 4.2732640980314484e+147]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.3917319243311995e+144, 3.644069016953863e+144]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.055509372138465e+141, 3.9236031719616834e+141]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-5.007059481721289e+138, 5.5324794181495356e+138]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-8.087389497689013e+135, 9.089705624228334e+135]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.2636445279585695e+133, 1.2604774856292935e+133]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-2.929929327999183e+130, 2.5981334177742545e+130]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-6.621998803435758e+127, 5.367714375220402e+127]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.2296417115712586e+125, 1.4984446397993e+125]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.681211448814023e+122, 3.31062547996481e+122]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.1933136362713286e+120, 1.0331487914455367e+120]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-3.7341020491196064e+117, 4.125929692747541e+117]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-1.5941901984448306e+115, 1.2823773677823227e+115]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# /home/hugo/anaconda3/lib/python3.6/site-packages/imageio/core/util.py:104: UserWarning: Conversion from float64 to uint8, range [-7.536382431869027e+112, 7.29550664971467e+112]
#   'range [{2}, {3}]'.format(dtype_str, out_type.__name__, mi, ma))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     481         fh = fp.fileno()
# --> 482         fp.flush()
#     483     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-e7542f3b34a4> in <module>()
#      98             imageio.imwrite('./16_clouds_hard_test/%s/B0 %s.png' % (t , (B_theta*180/np.pi) ) , im[:, :, 0])
#      99
# --> 100 generate_16_easy_MC()
#
# <ipython-input-2-e7542f3b34a4> in generate_16_easy_MC(N_theta, N_theta_test)
#      25             im = mc.random_cloud(mc_i)
#      26             im = im
# ---> 27             imageio.imwrite('./16_clouds_easy/%s/B0 %s.png' % (t , (B_theta*180/np.pi) ) , im[:, :, 0])
#      28
#      29     #generer test
#
# ~/anaconda3/lib/python3.6/site-packages/imageio/core/functions.py in imwrite(uri, im, format, **kwargs)
#     237     writer = get_writer(uri, format, 'i', **kwargs)
#     238     with writer:
# --> 239         writer.append_data(im)
#     240
#     241     # Return a result if there is any
#
# ~/anaconda3/lib/python3.6/site-packages/imageio/core/format.py in append_data(self, im, meta)
#     479             im = asarray(im)
#     480             # Call
# --> 481             return self._append_data(im, total_meta)
#     482
#     483         def set_meta_data(self, meta):
#
# ~/anaconda3/lib/python3.6/site-packages/imageio/plugins/pillow.py in _append_data(self, im, meta)
#     267             else:
#     268                 im = image_as_uint(im, bitdepth=8)
# --> 269             PillowFormat.Writer._append_data(self, im, meta)
#     270
#     271
#
# ~/anaconda3/lib/python3.6/site-packages/imageio/plugins/pillow.py in _append_data(self, im, meta)
#     161             if 'bits' in self._meta:
#     162                 img = img.quantize()  # Make it a P image, so bits arg is used
# --> 163             img.save(self._fp, format=self.format.plugin_id, **self._meta)
#     164             img.close()
#     165
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    1928                 init()
#    1929             try:
# -> 1930                 format = EXTENSION[ext]
#    1931             except KeyError:
#    1932                 raise ValueError('unknown file extension: {}'.format(ext))
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk)
#     819                 chunks.remove(cid)
#     820                 chunk(fp, cid, data)
# --> 821
#     822     ImageFile._save(im, _idat(fp, chunk),
#     823                     [("zip", (0, 0)+im.size, 0, rawmode)])
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     494                 while True:
#     495                     l, s, d = e.encode(bufsize)
# --> 496                     fp.write(d)
#     497                     if s:
#     498                         break
#
# KeyboardInterrupt:
