# %% [markdown]
# # 2018-06-06 - Psychophysics using psychopy
#
# On repasse sur un paradigme plus classique de psychophysique.

# %% [markdown]
# On récupère les initiales :

# %%
exp_info = '2018-06-06_MP'
print (exp_info)
# Out:
# 2018-06-06_MP

# %% [markdown]
# On défini la génération de MotionClouds :

# %%
import numpy as np
import MotionClouds as mc
import matplotlib.pyplot as plt
import os
import imageio
import random

downscale = 1
fig_width = 21
fx, fy, ft = mc.get_grids(mc.N_X/downscale, mc.N_Y/downscale, 1)

# generates a cloud of given theta and b_theta
def generate_random_cloud(theta, B_theta):
    mc_i = mc.envelope_gabor(fx, fy, ft, V_X=0., V_Y=0.,
                             B_V=0, theta=theta, B_theta=B_theta)
    im = mc.random_cloud(mc_i)
    im = (mc.rectif(im) * 255).astype('uint8')
    fname = '/tmp/%s_%s.png' % (theta, B_theta)
    imageio.imwrite(fname, im[:, :, 0])
    return fname

# %% [markdown]
# On définit les paramètres et on teste :

# %%
from psychopy import visual, core, event
import MotionClouds as MC

test_length = 150  # number of trials
#trial_length = 2.6  # length of trial, in second
fixation_length = .5  # length of fixation, in second
stim1_length = 0.25  # length of first stim, in second
stim2_length = 0.25  # length of the second stim, in second

fullscr = False

fullscr = True

# Psychopy window
win = visual.Window(fullscr=fullscr, color=[0,0,0], winType='pygame', monitor='testMonitor', units='height')
mouse = event.Mouse(visible=False)

fixation = visual.ShapeStim(vertices='cross', win=win, size=0.05, pos=[0, 0], fillColor='black', units='height')
fixation.autolog = False

MC1 = generate_random_cloud(np.pi/2, B_theta=np.pi/2)
bitmap1 = visual.ImageStim(win, MC1, mask='gauss', size=0.8, units='height')
bitmap1.autolog = False
bitmap2 = visual.ImageStim(win, MC1, mask='gauss', size=0.8, units='height')
bitmap2.autolog = False
#bitmap3 = visual.ImageStim(win, '%s.png' %
#                           str(2 * (np.pi/3)), mask='circle')
#bitmap3.autolog = False


#msg = visual.TextStim(win, text='<- LEFT or RIGHT ->', color='black')
msg = visual.TextStim(win, text='?', color='black')

#shift_dict = {'right': 2,
#              'left':  3}


# Answer list
ans_list = []
N_B_thetas = 5
B_thetas = np.pi*np.logspace(-7, 0, N_B_thetas, base=2)
    
std_theta = np.pi/6
for trial in range(test_length):
    clock = core.Clock()
    fixation.draw()
    win.flip()
    
    # Shift to left (3) or to right (2) ?
    #shift = random.randint(2, 3)
    theta = np.clip(std_theta *  np.random.randn(), -np.pi/4, np.pi/4)

    # MC generation
    B_theta = B_thetas[random.randint(0, N_B_thetas-1)]

    MC1 = generate_random_cloud(np.pi/2, B_theta=B_theta)
    bitmap1.setImage(MC1)

    MC2 = generate_random_cloud(np.pi/2 - theta, B_theta=B_theta)  # if shift = 2
    bitmap2.setImage(MC2)

    #MC3 = generate_random_cloud(2 * (np.pi/3), B_theta=B_theta)  # if shift = 3
    # MC to psychopy objects
    
    # Times the trial
    while clock.getTime() < fixation_length + stim1_length + stim2_length:
        if 0.0 <= clock.getTime() < fixation_length:  # fixation
            fixation.draw()
        if fixation_length + 0.01 <= clock.getTime() < fixation_length + stim1_length:
            bitmap1.draw()
        if fixation_length + stim1_length <= clock.getTime() < fixation_length + stim1_length + stim2_length:
            bitmap2.draw()
        win.flip()

    # display orientation choice
    msg.draw()
    win.flip()

    # answer using the keyboard
    while True:
        ans = event.waitKeys()

        if len(ans) > 0:
            if ans[0] in ['escape', 'q']:
                win.close()
                core.quit()
            elif ans[0] in ['left', 'right']:
                correct = (np.sign(theta) > 0) and (ans[0]=='right')
                print('At trial ', trial, 'Angle=', '%3.3f' % (theta*180/np.pi), 'answer is ', ans[0], '(correct=', correct, '); bandwidth=', '%.3f' % (B_theta*180/np.pi))
                break

    # Output shape per trial is : trial number, shift direction, answered shift and b_theta
    ans_list.append([trial, theta, ans[0], B_theta])

win.close()
# Out:
# At trial  0 Angle= -24.919 answer is  left (correct= False ); bandwidth= 53.514
# At trial  1 Angle= -45.000 answer is  left (correct= False ); bandwidth= 4.730
# At trial  2 Angle= -29.916 answer is  left (correct= False ); bandwidth= 4.730
# At trial  3 Angle= -30.777 answer is  left (correct= False ); bandwidth= 4.730
# At trial  4 Angle= -13.454 answer is  left (correct= False ); bandwidth= 4.730
# At trial  5 Angle= 0.465 answer is  left (correct= False ); bandwidth= 15.910
# At trial  6 Angle= 41.899 answer is  right (correct= True ); bandwidth= 180.000
# At trial  7 Angle= 3.934 answer is  right (correct= True ); bandwidth= 15.910
# At trial  8 Angle= -20.990 answer is  left (correct= False ); bandwidth= 53.514
# At trial  9 Angle= 40.437 answer is  right (correct= True ); bandwidth= 53.514
# At trial  10 Angle= -3.201 answer is  right (correct= False ); bandwidth= 180.000
# At trial  11 Angle= -15.402 answer is  left (correct= False ); bandwidth= 53.514
# At trial  12 Angle= -34.321 answer is  left (correct= False ); bandwidth= 1.406
# At trial  13 Angle= -15.278 answer is  left (correct= False ); bandwidth= 180.000
# At trial  14 Angle= -36.944 answer is  left (correct= False ); bandwidth= 1.406
# At trial  15 Angle= -45.000 answer is  left (correct= False ); bandwidth= 4.730
# At trial  16 Angle= 45.000 answer is  right (correct= True ); bandwidth= 4.730
# At trial  17 Angle= -14.966 answer is  left (correct= False ); bandwidth= 180.000
# At trial  18 Angle= -28.965 answer is  left (correct= False ); bandwidth= 1.406
# At trial  19 Angle= -0.970 answer is  left (correct= False ); bandwidth= 1.406
# At trial  20 Angle= -3.715 answer is  left (correct= False ); bandwidth= 1.406
# At trial  21 Angle= -22.553 answer is  left (correct= False ); bandwidth= 53.514
# At trial  22 Angle= 5.260 answer is  right (correct= True ); bandwidth= 15.910
# At trial  23 Angle= 2.188 answer is  right (correct= True ); bandwidth= 180.000
# At trial  24 Angle= 10.394 answer is  right (correct= True ); bandwidth= 180.000
# At trial  25 Angle= 2.195 answer is  right (correct= True ); bandwidth= 1.406
# At trial  26 Angle= 25.708 answer is  left (correct= False ); bandwidth= 53.514
# At trial  27 Angle= 34.351 answer is  right (correct= True ); bandwidth= 15.910
# At trial  28 Angle= 45.000 answer is  left (correct= False ); bandwidth= 180.000
# At trial  29 Angle= 20.935 answer is  right (correct= True ); bandwidth= 15.910
# At trial  30 Angle= 22.751 answer is  right (correct= True ); bandwidth= 4.730
# At trial  31 Angle= 3.728 answer is  left (correct= False ); bandwidth= 53.514
# At trial  32 Angle= -45.000 answer is  left (correct= False ); bandwidth= 4.730
# At trial  33 Angle= 45.000 answer is  left (correct= False ); bandwidth= 180.000
# At trial  34 Angle= 24.797 answer is  right (correct= True ); bandwidth= 53.514
# At trial  35 Angle= 32.260 answer is  right (correct= True ); bandwidth= 53.514
# At trial  36 Angle= -32.949 answer is  right (correct= False ); bandwidth= 180.000
# At trial  37 Angle= 23.577 answer is  right (correct= True ); bandwidth= 15.910
# At trial  38 Angle= -24.607 answer is  left (correct= False ); bandwidth= 4.730
# At trial  39 Angle= 14.026 answer is  right (correct= True ); bandwidth= 4.730
# At trial  40 Angle= -45.000 answer is  left (correct= False ); bandwidth= 4.730
# At trial  41 Angle= -22.571 answer is  left (correct= False ); bandwidth= 1.406
# At trial  42 Angle= 21.937 answer is  right (correct= True ); bandwidth= 15.910
# At trial  43 Angle= -34.257 answer is  right (correct= False ); bandwidth= 180.000
# At trial  44 Angle= 17.744 answer is  right (correct= True ); bandwidth= 180.000
# At trial  45 Angle= 45.000 answer is  right (correct= True ); bandwidth= 4.730
# At trial  46 Angle= -16.998 answer is  left (correct= False ); bandwidth= 180.000
# At trial  47 Angle= -3.978 answer is  left (correct= False ); bandwidth= 1.406
# At trial  48 Angle= 45.000 answer is  right (correct= True ); bandwidth= 53.514
# At trial  49 Angle= -26.556 answer is  left (correct= False ); bandwidth= 180.000
# At trial  50 Angle= 45.000 answer is  right (correct= True ); bandwidth= 15.910
# At trial  51 Angle= 41.985 answer is  right (correct= True ); bandwidth= 15.910
# At trial  52 Angle= -12.429 answer is  left (correct= False ); bandwidth= 4.730
# At trial  53 Angle= -17.024 answer is  left (correct= False ); bandwidth= 4.730
# At trial  54 Angle= 17.397 answer is  right (correct= True ); bandwidth= 1.406
# At trial  55 Angle= -41.140 answer is  left (correct= False ); bandwidth= 53.514
# At trial  56 Angle= -14.513 answer is  left (correct= False ); bandwidth= 180.000
# At trial  57 Angle= -13.861 answer is  right (correct= False ); bandwidth= 180.000
# At trial  58 Angle= 14.637 answer is  right (correct= True ); bandwidth= 53.514
# At trial  59 Angle= 9.570 answer is  left (correct= False ); bandwidth= 180.000
# At trial  60 Angle= -45.000 answer is  left (correct= False ); bandwidth= 15.910
# At trial  61 Angle= -6.366 answer is  left (correct= False ); bandwidth= 4.730
# At trial  62 Angle= -34.870 answer is  left (correct= False ); bandwidth= 180.000
# At trial  63 Angle= 40.750 answer is  right (correct= True ); bandwidth= 180.000
# At trial  64 Angle= -25.708 answer is  right (correct= False ); bandwidth= 180.000
# At trial  65 Angle= -35.858 answer is  left (correct= False ); bandwidth= 1.406
# At trial  66 Angle= -17.953 answer is  left (correct= False ); bandwidth= 4.730
# At trial  67 Angle= 18.795 answer is  right (correct= True ); bandwidth= 4.730
# At trial  68 Angle= 0.157 answer is  left (correct= False ); bandwidth= 180.000
# At trial  69 Angle= -18.519 answer is  left (correct= False ); bandwidth= 180.000
# At trial  70 Angle= -42.785 answer is  left (correct= False ); bandwidth= 180.000
# At trial  71 Angle= 7.244 answer is  right (correct= True ); bandwidth= 15.910
# At trial  72 Angle= -45.000 answer is  left (correct= False ); bandwidth= 4.730
# At trial  73 Angle= 20.972 answer is  left (correct= False ); bandwidth= 53.514
# At trial  74 Angle= 9.168 answer is  right (correct= True ); bandwidth= 180.000
# At trial  75 Angle= 12.505 answer is  right (correct= True ); bandwidth= 15.910
# At trial  76 Angle= -12.675 answer is  left (correct= False ); bandwidth= 4.730
# At trial  77 Angle= -21.264 answer is  left (correct= False ); bandwidth= 53.514
# At trial  78 Angle= 13.303 answer is  right (correct= True ); bandwidth= 4.730
# At trial  79 Angle= -16.401 answer is  left (correct= False ); bandwidth= 1.406
# At trial  80 Angle= -8.200 answer is  left (correct= False ); bandwidth= 180.000
# At trial  81 Angle= 1.964 answer is  right (correct= True ); bandwidth= 4.730
# At trial  82 Angle= 17.065 answer is  right (correct= True ); bandwidth= 53.514
# At trial  83 Angle= 45.000 answer is  right (correct= True ); bandwidth= 1.406
# At trial  84 Angle= -4.521 answer is  left (correct= False ); bandwidth= 180.000
# At trial  85 Angle= -31.465 answer is  left (correct= False ); bandwidth= 53.514
# At trial  86 Angle= -1.921 answer is  left (correct= False ); bandwidth= 4.730
# At trial  87 Angle= -9.073 answer is  left (correct= False ); bandwidth= 53.514
# At trial  88 Angle= 10.799 answer is  right (correct= True ); bandwidth= 180.000
# At trial  89 Angle= 30.876 answer is  right (correct= True ); bandwidth= 15.910
# At trial  90 Angle= 45.000 answer is  right (correct= True ); bandwidth= 15.910
# At trial  91 Angle= -24.507 answer is  right (correct= False ); bandwidth= 180.000
# At trial  92 Angle= -12.604 answer is  left (correct= False ); bandwidth= 4.730
# At trial  93 Angle= 5.111 answer is  right (correct= True ); bandwidth= 1.406
# At trial  94 Angle= -3.058 answer is  left (correct= False ); bandwidth= 180.000
# At trial  95 Angle= 5.433 answer is  left (correct= False ); bandwidth= 180.000
# At trial  96 Angle= 45.000 answer is  right (correct= True ); bandwidth= 15.910
# At trial  97 Angle= -42.628 answer is  left (correct= False ); bandwidth= 4.730
# At trial  98 Angle= -36.672 answer is  left (correct= False ); bandwidth= 53.514
# At trial  99 Angle= 23.058 answer is  right (correct= True ); bandwidth= 1.406
# At trial  100 Angle= 11.072 answer is  right (correct= True ); bandwidth= 180.000
# At trial  101 Angle= 7.618 answer is  right (correct= True ); bandwidth= 1.406
# At trial  102 Angle= -35.304 answer is  left (correct= False ); bandwidth= 1.406
# At trial  103 Angle= 17.110 answer is  right (correct= True ); bandwidth= 4.730
# At trial  104 Angle= 40.073 answer is  right (correct= True ); bandwidth= 4.730
# At trial  105 Angle= 7.556 answer is  right (correct= True ); bandwidth= 15.910
# At trial  106 Angle= -11.937 answer is  left (correct= False ); bandwidth= 53.514
# At trial  107 Angle= 31.595 answer is  right (correct= True ); bandwidth= 4.730
# At trial  108 Angle= 14.562 answer is  right (correct= True ); bandwidth= 15.910
# At trial  109 Angle= 11.236 answer is  right (correct= True ); bandwidth= 4.730
# At trial  110 Angle= 24.135 answer is  right (correct= True ); bandwidth= 1.406
# At trial  111 Angle= 45.000 answer is  right (correct= True ); bandwidth= 1.406
# At trial  112 Angle= 5.103 answer is  right (correct= True ); bandwidth= 4.730
# At trial  113 Angle= -36.209 answer is  left (correct= False ); bandwidth= 53.514
# At trial  114 Angle= 0.926 answer is  right (correct= True ); bandwidth= 180.000
# At trial  115 Angle= -16.579 answer is  left (correct= False ); bandwidth= 1.406
# At trial  116 Angle= -5.027 answer is  left (correct= False ); bandwidth= 15.910
# At trial  117 Angle= 39.744 answer is  right (correct= True ); bandwidth= 15.910
# At trial  118 Angle= -40.863 answer is  right (correct= False ); bandwidth= 180.000
# At trial  119 Angle= -3.531 answer is  left (correct= False ); bandwidth= 1.406
# At trial  120 Angle= -5.414 answer is  left (correct= False ); bandwidth= 53.514
# At trial  121 Angle= 16.168 answer is  left (correct= False ); bandwidth= 180.000
# At trial  122 Angle= 45.000 answer is  right (correct= True ); bandwidth= 180.000
# At trial  123 Angle= -0.603 answer is  right (correct= False ); bandwidth= 4.730
# At trial  124 Angle= -1.853 answer is  left (correct= False ); bandwidth= 180.000
# At trial  125 Angle= -0.332 answer is  left (correct= False ); bandwidth= 53.514
# At trial  126 Angle= 4.175 answer is  right (correct= True ); bandwidth= 4.730
# At trial  127 Angle= 8.718 answer is  right (correct= True ); bandwidth= 53.514
# At trial  128 Angle= -44.120 answer is  left (correct= False ); bandwidth= 180.000
# At trial  129 Angle= 36.817 answer is  right (correct= True ); bandwidth= 15.910
# At trial  130 Angle= 8.990 answer is  right (correct= True ); bandwidth= 180.000
# At trial  131 Angle= -44.883 answer is  right (correct= False ); bandwidth= 180.000
# At trial  132 Angle= -22.341 answer is  left (correct= False ); bandwidth= 53.514
# At trial  133 Angle= 45.000 answer is  right (correct= True ); bandwidth= 4.730
# At trial  134 Angle= -1.971 answer is  right (correct= False ); bandwidth= 53.514
# At trial  135 Angle= -38.523 answer is  left (correct= False ); bandwidth= 180.000
# At trial  136 Angle= -10.401 answer is  left (correct= False ); bandwidth= 15.910
# At trial  137 Angle= -7.400 answer is  left (correct= False ); bandwidth= 15.910
# At trial  138 Angle= -4.888 answer is  left (correct= False ); bandwidth= 1.406
# At trial  139 Angle= -24.081 answer is  left (correct= False ); bandwidth= 180.000
# At trial  140 Angle= 22.862 answer is  right (correct= True ); bandwidth= 53.514
# At trial  141 Angle= 6.677 answer is  right (correct= True ); bandwidth= 4.730
# At trial  142 Angle= -45.000 answer is  left (correct= False ); bandwidth= 1.406
# At trial  143 Angle= -30.159 answer is  left (correct= False ); bandwidth= 180.000
# At trial  144 Angle= -1.487 answer is  left (correct= False ); bandwidth= 53.514
# At trial  145 Angle= 1.204 answer is  left (correct= False ); bandwidth= 53.514
# At trial  146 Angle= -17.904 answer is  left (correct= False ); bandwidth= 1.406
# At trial  147 Angle= -24.371 answer is  left (correct= False ); bandwidth= 180.000
# At trial  148 Angle= -9.796 answer is  left (correct= False ); bandwidth= 180.000
# At trial  149 Angle= -3.538 answer is  left (correct= False ); bandwidth= 4.730
# 1.6486 	WARNING 	User requested fullscreen with size [800 600], but screen is actually [1366, 768]. Using actual size

# %%
import pickle
pickle.dump(ans_list, open('Psychophys_discrim_%s.p' % exp_info, 'wb'))
